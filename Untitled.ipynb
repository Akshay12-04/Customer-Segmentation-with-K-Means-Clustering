# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\aksha\miniconda3\lib\site-packages (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\aksha\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
os.getcwd()
# Out:
# 'C:\\Users\\aksha\\Python'

# %%
pip install seaborn
# Out:
# Requirement already satisfied: seaborn in c:\users\aksha\miniconda3\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\aksha\miniconda3\lib\site-packages (from seaborn) (1.26.4)
# Requirement already satisfied: pandas>=1.2 in c:\users\aksha\miniconda3\lib\site-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\aksha\miniconda3\lib\site-packages (from seaborn) (3.9.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\aksha\miniconda3\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aksha\miniconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\aksha\miniconda3\lib\site-packages (from pandas>=1.2->seaborn) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\aksha\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\aksha\miniconda3\lib\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\aksha\miniconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\aksha\miniconda3\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\aksha\miniconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\aksha\miniconda3\lib\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
df=pd.read_csv('Mall_Customers.csv')
df.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (200, 5)

# %%
df.shape
# Out:
# (200, 5)

# %%
plt.figure(1, figsize=(16,10))
sns.pairplot(data=df, hue='Gender')
plt.show()

# %%
plt.figure(1, figsize=(4,4))
sns.countplot(x='Gender', data=df)
plt.show()

# %%
plt.figure(1, figsize=(16,4))
n = 0 
for x in ['Age', 'Annual Income (k$)', 'Spending Score (1-100)']:
    n += 1
    plt.subplot(1, 3, n)
    plt.subplots_adjust(hspace=0.5 , wspace=0.5)
    sns.histplot(df[x], bins=10)
    plt.title('Distplot of {}'.format(x))
plt.show()

# %%
X = df.iloc[:, -2:]

# %%
km_inertias, km_scores = [], []

for k in range(2, 11):
    km = KMeans(n_clusters=kfi).t(X)
    km_inertias.append(km.inertia_)
    km_scores.append(silhouette_score(X, km.labels_))
    
sns.lineplot(x=range(2, 11), y=km_inertias)
plt.title('Elbow Graph / Inertia Depending on K')
plt.show()

# %%
sns.lineplot(x=range(2, 11), y=km_scores)
plt.title('Scores Depending on K')
plt.show()

# %%
X = df.iloc[:, -3:]

# %%
km_inertias, km_scores = [], []

for k in range(2, 11):
    km = KMeans(n_clusters=k).fit(X)
    km_inertias.append(km.inertia_)
    km_scores.append(silhouette_score(X, km.labels_))
    
sns.lineplot(x=range(2, 11), y=km_inertias)
plt.title('Elbow Graph / Inertia Depending on K')
plt.show()

# %%
sns.lineplot(x=range(2, 11), y=km_scores)
plt.title('Scores Depending on K')
plt.show()

# %%
km = KMeans(n_clusters=5).fit(X)

# %%
# K-Means visualization on pair of 2 features
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X.iloc[:, 1], y=X.iloc[:, 2], hue=km.labels_)
plt.show()

# %%
# K-Means visualization on another pair of 2 features
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X.iloc[:, 0], y=X.iloc[:, 1], hue=km.labels_)
plt.show()

# %%
# K-Means visualization on the last pair of 2 features
plt.figure(figsize=(10, 6))
sns.scatterplot(x=X.iloc[:, 0], y=X.iloc[:, 2], hue=km.labels_)
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(8,8))
ax = Axes3D(fig)

xs = X.iloc[:, 0]
ys = X.iloc[:, 1]
zs = X.iloc[:, 2]
ax.scatter(xs, ys, zs, s=50, alpha=0.6, c=km.labels_)

ax.set_xlabel('Age')
ax.set_ylabel('Annual income')
ax.set_zlabel('Spending score')

plt.show()

# %%
# Profiles of customers
X['label'] = km.labels_

# %%
X.label.value_counts()
# Out:
# label
# 4    52
# 0    50
# 1    39
# 2    38
# 3    21
# Name: count, dtype: int64

# %%
for k in range(5):
    print(f'cluster nb : {k}')
    print(X[X.label == k].describe().iloc[[0, 1, 3, 7], :-1])
    print('\n\n')
# Out:
# cluster nb : 0
#         Age  Annual Income (k$)  Spending Score (1-100)
# count  50.0               50.00                    50.0
# mean   24.8               41.46                    63.7
# min    18.0               15.00                    41.0
# max    35.0               67.00                    99.0
#
#
#
# cluster nb : 1
#              Age  Annual Income (k$)  Spending Score (1-100)
# count  39.000000           39.000000               39.000000
# mean   32.692308           86.538462               82.128205
# min    27.000000           69.000000               63.000000
# max    40.000000          137.000000               97.000000
#
#
#
# cluster nb : 2
#              Age  Annual Income (k$)  Spending Score (1-100)
# count  38.000000                38.0               38.000000
# mean   40.394737                87.0               18.631579
# min    19.000000                70.0                1.000000
# max    59.000000               137.0               40.000000
#
#
#
# cluster nb : 3
#              Age  Annual Income (k$)  Spending Score (1-100)
# count  21.000000           21.000000                21.00000
# mean   44.142857           25.142857                19.52381
# min    19.000000           15.000000                 3.00000
# max    67.000000           39.000000                40.00000
#
#
#
# cluster nb : 4
#              Age  Annual Income (k$)  Spending Score (1-100)
# count  52.000000           52.000000               52.000000
# mean   53.711538           54.423077               48.730769
# min    32.000000           38.000000               35.000000
# max    70.000000           69.000000               60.000000

# %%
for k in range(5):
    print(f'cluster nb : {k}')
    print(X[X.label == k].describe().iloc[[0, 1, 3, 7], :-1])
    print('\n\n')
# Out:
# cluster nb : 0
#         Age  Annual Income (k$)  Spending Score (1-100)
# count  50.0               50.00                    50.0
# mean   24.8               41.46                    63.7
# min    18.0               15.00                    41.0
# max    35.0               67.00                    99.0
#
#
#
# cluster nb : 1
#              Age  Annual Income (k$)  Spending Score (1-100)
# count  39.000000           39.000000               39.000000
# mean   32.692308           86.538462               82.128205
# min    27.000000           69.000000               63.000000
# max    40.000000          137.000000               97.000000
#
#
#
# cluster nb : 2
#              Age  Annual Income (k$)  Spending Score (1-100)
# count  38.000000                38.0               38.000000
# mean   40.394737                87.0               18.631579
# min    19.000000                70.0                1.000000
# max    59.000000               137.0               40.000000
#
#
#
# cluster nb : 3
#              Age  Annual Income (k$)  Spending Score (1-100)
# count  21.000000           21.000000                21.00000
# mean   44.142857           25.142857                19.52381
# min    19.000000           15.000000                 3.00000
# max    67.000000           39.000000                40.00000
#
#
#
# cluster nb : 4
#              Age  Annual Income (k$)  Spending Score (1-100)
# count  52.000000           52.000000               52.000000
# mean   53.711538           54.423077               48.730769
# min    32.000000           38.000000               35.000000
# max    70.000000           69.000000               60.000000
